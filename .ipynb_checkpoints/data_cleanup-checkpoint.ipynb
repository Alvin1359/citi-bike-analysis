# %%
import pandas as pd
import glob
import os

# %%
path = os.getcwd()
filenames = glob.glob(os.path.join(path + "/resources", "*.csv"))
  
dfs = []

# loop over the list of csv files
for filename in filenames:

    dfs.append(pd.read_csv(filename, index_col=None, header=0))

# Concatenate all data into one DataFrame

data_2020 = pd.concat(dfs, axis=0, ignore_index=True)
data_2020
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
# Checking for NaN values
data_2020.isnull().sum().sum()
# Out:
# 0

# %%
# Changing encoders for gender (0 = Unknown, 1 = male, 2 = female)
data_2020['gender']= data_2020['gender'].map({0: "Unknown", 1: "Male", 2: "Female"})

# %%
# Formatting time columns to pandas datetime format
data_2020["starttime"]= pd.to_datetime(data_2020["starttime"])
data_2020["stoptime"]= pd.to_datetime(data_2020["stoptime"])

# %%
# Checking for spelling mistakes in station names
data_2020["start station name"].value_counts()
# Out:
# Grove St PATH                 22930
# Newport Pkwy                  19844
# Liberty Light Rail            16933
# Hamilton Park                 14718
# Sip Ave                       13663
# Marin Light Rail              13615
# Newport PATH                  12855
# Harborside                    12757
# Columbus Dr at Exchange Pl    12586
# JC Medical Center             10795
# City Hall                      9715
# Morris Canal                   9209
# Warren St                      9177
# Washington St                  8855
# Paulus Hook                    8069
# Newark Ave                     7872
# Van Vorst Park                 7301
# Columbus Drive                 7285
# Jersey & 3rd                   6075
# McGinley Square                5732
# Brunswick St                   5485
# Brunswick & 6th                5483
# Jersey & 6th St                5388
# Manila & 1st                   5346
# Lincoln Park                   5339
# Grand St                       5165
# ...

# %%
data_2020.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           226 2020-01-01 00:04:50.192 2020-01-01 00:08:37.037
# 1           377 2020-01-01 00:16:01.670 2020-01-01 00:22:19.080
# 2           288 2020-01-01 00:17:33.877 2020-01-01 00:22:22.442
# 3           435 2020-01-01 00:32:05.902 2020-01-01 00:39:21.066
# 4           231 2020-01-01 00:46:19.678 2020-01-01 00:50:11.344
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# ...

# %%
data_2020.to_csv("resources/2020-citibike-tripdata.csv", index=False)
